# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from pandas.core.frame import DataFrame
from random import shuffle
import seaborn as sns

# %%
total = pd.read_excel('../data/total_census_occupations.xlsx')

# %%
def categorize_white(percent):
    if percent < 67.2: return 'less than pop'
    elif percent == 67.2: return 'equal to pop'
    elif percent > 67.2: return 'more than pop'
    else: return np.nan

total['White Representation'] = total['White Percent'].apply(categorize_white)

def categorize_black(percent):
    if percent < 11: return 'less than pop'
    elif percent == 11: return 'equal to pop'
    elif percent > 11: return 'more than pop'
    else: return np.nan

total['Black Representation'] = total['Black Percent'].apply(categorize_black)

def categorize_asian(percent):
    if percent < 5.9: return 'less than pop'
    elif percent == 5.9: return 'equal to pop'
    elif percent > 5.9: return 'more than pop'
    else: return np.nan

total['Asian Representation'] = total['Asian Percent'].apply(categorize_asian)

def categorize_hispanic(percent):
    if percent < 15.8: return 'less than pop'
    elif percent == 15.8: return 'equal to pop'
    elif percent > 15.8: return 'more than pop'
    else: return np.nan

total['Hispanic Representation'] = total['Hispanic Percent'].apply(categorize_hispanic)

# %%
total.loc[total['White Representation']=='less than pop']
# Out:
#                                            Occupation  Total Estimate  \
# 5                         ..Computer systems analysts        473135.0
# 8   ..Software developers, applications and system...       1050915.0
# 14                  ..Computer occupations, all other        462620.0
# 18  ..Miscellaneous mathematical science occupatio...         45945.0
# 26                      ..Computer hardware engineers         52265.0
# 43  ..Medical scientists and life scientists, all ...        133205.0
# 49                   ..Physical scientists, all other        200220.0
# 57                           ..Biological technicians         16855.0
#
#     Total MOE3  White Estimate  White MOE3  White Percent White MOE3.1  \
# 5       5172.3        310130.0      3795.1           65.5          0.5
# 8       9784.1        613055.0      6411.0           58.3          0.3
# 14      4629.8        309595.0      4005.1           66.9          0.6
# 18      1637.4         30155.0      1197.9           65.6          1.6
# 26      1567.5         30625.0      1172.3           58.6          1.7
# 43      2941.8         76770.0      2064.4           57.6          0.9
# 49      3791.9        128895.0      2752.5           64.4          0.6
# 57       975.6         11305.0       763.2           67.1          2.9
#
#     Black Estimate  Black MOE3  Black Percent  ... Asian MOE3.1  \
# 5          40245.0      1616.2            8.5  ...          0.4
# 8          47520.0      1795.0            4.5  ...          0.3
# 14         48540.0      1684.1           10.5  ...          0.4
# 18          3185.0       497.1            6.9  ...          1.4
# 26          3505.0       469.8            6.7  ...          1.5
# 43          6745.0       596.7            5.1  ...          1.0
# 49          6790.0       589.3            3.4  ...          0.6
# 57          1405.0       250.3            8.3  ...          1.8
#
#     Hispanic Estimate  Hispanic MOE3  Hispanic Percent Hispanic MOE3.1  \
# 5             32075.0         1393.9               6.8             0.3
# 8             49565.0         1930.4               4.7             0.2
# 14            38425.0         1736.3               8.3             0.3
# 18             2700.0          376.5               5.9             0.8
# 26             3235.0          473.0               6.2             0.9
# 43             7965.0          693.0               6.0             0.5
# 49            10040.0          719.3               5.0             0.4
# 57             2085.0          353.1              12.4             1.9
#
#         Type  White Representation  Black Representation Asian Representation  \
# 5   subfield         less than pop         less than pop        more than pop
# 8   subfield         less than pop         less than pop        more than pop
# 14  subfield         less than pop         less than pop        more than pop
# 18  subfield         less than pop         less than pop        more than pop
# 26  subfield         less than pop         less than pop        more than pop
# 43  subfield         less than pop         less than pop        more than pop
# 49  subfield         less than pop         less than pop        more than pop
# 57  subfield         less than pop         less than pop        more than pop
#
#    Hispanic Representation
# 5            less than pop
# 8            less than pop
# 14           less than pop
# 18           less than pop
# 26           less than pop
# 43           less than pop
# 49           less than pop
# 57           less than pop
#
# [8 rows x 24 columns]

# %%
wrep_data = total.groupby('White Representation').size().reset_index().rename(columns={0:'n_wrep'})
display(wrep_data)
# Out:
#   White Representation  n_wrep
# 0         equal to pop       2
# 1        less than pop       8
# 2        more than pop      51

# %%
bartotal = total.loc[total['White Estimate']>=5636170.0]
bartotal
# Out:
#                           Occupation  Total Estimate  Total MOE3  \
# 0  Civilian employed age 25 and over     125850932.0    110885.4
# 1                        Total STEM2       7980038.0     56752.8
#
#    White Estimate  White MOE3  White Percent White MOE3.1  Black Estimate  \
# 0      84585827.0     87601.7           67.2         <0.1      13908136.0
# 1       5636170.0     36858.0           70.6          0.1        506349.0
#
#    Black MOE3  Black Percent  ... Asian MOE3.1  Hispanic Estimate  \
# 0     18828.1           11.0  ...         <0.1         19918842.0
# 1      6731.4            6.3  ...          0.1           560030.0
#
#    Hispanic MOE3  Hispanic Percent Hispanic MOE3.1        Type  \
# 0        21368.8              15.8            <0.1       Total
# 1         9645.3               7.0             0.1  Total STEM
#
#    White Representation  Black Representation Asian Representation  \
# 0          equal to pop          equal to pop         equal to pop
# 1         more than pop         less than pop        more than pop
#
#   Hispanic Representation
# 0            equal to pop
# 1           less than pop
#
# [2 rows x 24 columns]

# %%
df = bartotal[['White Percent', 'Black Percent']].transpose()
df.columns = ['civilian', 'stem']
df
# Out:
#                civilian  stem
# White Percent      67.2  70.6
# Black Percent      11.0   6.3

# %%
totalpercent = [67.2, 11.0, 5.9, 15.8]
stempercent = [70.6, 6.3, 16.0, 7.0]
index = ['White Percent', 'Black Percent', 'Asian Percent','Hispanic Percent']
df = pd.DataFrame({'totalpercent': totalpercent,'stempercent': stempercent}, index=index)
ax = df.plot.bar(rot=0, figsize=(10,8))

# %%
totalemp = [84585827.0, 13908136.0, 7438127.0, 19918842.0]
stememp = [5636170.0, 506349.0, 1277489.0, 560030.0]
index1 = ['White Employment', 'Black Employment', 'Asian Employment','Hispanic Employment']
df2 = pd.DataFrame({'totalemp': totalemp,'stememp': stememp}, index=index1)
ax2 = df2.plot.bar(rot=0, figsize=(10,8))

# %%
wltp = 0.0
wmtp = 0.0
bltp = 0.0
bmtp = 0.0
altp = 0.0
amtp = 0.0
hltp = 0.0
hmtp = 0.0

for i, row in total.iterrows():
    val = row['White Representation']
    typ = row['Type']
    if typ == 'subfield':
        if val == 'less than pop':
            wltp += row['White Estimate']
        if val == 'more than pop':
            wmtp += row['White Estimate']

for i, row in total.iterrows():
    val = row['Black Representation']
    typ = row['Type']
    if typ == 'subfield':
        if val == 'less than pop':
            bltp += row['Black Estimate']
        if val == 'more than pop':
            bmtp += row['Black Estimate']

for i, row in total.iterrows():
    val = row['Asian Representation']
    typ = row['Type']
    if typ == 'subfield':
        if val == 'less than pop':
            altp += row['Asian Estimate']
        if val == 'more than pop':
            amtp += row['Asian Estimate']

for i, row in total.iterrows():
    val = row['Hispanic Representation']
    typ = row['Type']
    if typ == 'subfield':
        if val == 'less than pop':
            hltp += row['Hispanic Estimate']
        if val == 'more than pop':
            hmtp += row['Hispanic Estimate']

# %%
ltp = [wltp, bltp, altp, hltp]
mtp = [wmtp, bmtp, amtp, hmtp]
index2 = ['White Employment', 'Black Employment', 'Asian Employment','Hispanic Employment']
df3 = pd.DataFrame({'ltp': ltp,'mtp': mtp}, index=index2)
ax3 = df3.plot.bar(rot=0, figsize=(10,8))
