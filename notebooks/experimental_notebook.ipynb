# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from pandas.core.frame import DataFrame
from random import shuffle
import seaborn as sns
from IPython.display import display, HTML

display(HTML("<style>.container{ width:95% !important;}</style>"))
# Out:
# <style>.container{ width:95% !important;}</style>

# %%
total = pd.read_excel('../data/total_census_occupations.xlsx')
display(total)
# Out:
#                                            Occupation  Total Estimate  \
# 0                   Civilian employed age 25 and over     125850932.0
# 1                                         Total STEM2       7980038.0
# 2                              .Computer Occupations:       4120460.0
# 3         ..Computer and information systems managers        545580.0
# 4      ..Computer and information research scientists         15875.0
# ..                                                ...             ...
# 56        ..Agricultural and food science technicians         29880.0
# 57                           ..Biological technicians         16855.0
# 58                             ..Chemical technicians         59555.0
# 59  ..Geological and petroleum technicians and nuc...         18445.0
# 60  ..Miscellaneous life, physical, and social sci...        135100.0
#
#     Total MOE3  White Estimate  White MOE3  White Percent White MOE3.1  \
# ...

# %%
total['White Percent'].median()
# Out:
# 72.1

# %%
total['White Percent'].mean()
# Out:
# 74.00327868852459

# %%
total[['White Percent', 'Black Percent', 'Asian Percent', 'Hispanic Percent']]
# Out:
#     White Percent  Black Percent  Asian Percent  Hispanic Percent
# 0            67.2           11.0            5.9              15.8
# 1            70.6            6.3           16.0               7.0
# 2            67.2            7.2           18.9               6.6
# 3            74.5            5.9           13.5               6.1
# 4            69.2            7.2           17.7               6.0
# ..            ...            ...            ...               ...
# 56           71.7            7.6            4.5              16.2
# 57           67.1            8.3           12.2              12.4
# 58           71.9           12.3            6.6               9.1
# 59           76.9            7.1            3.6              12.4
# 60           70.2            8.1           11.3              10.4
#
# [61 rows x 4 columns]

# %%
print('\nMultiple stats for values in column A:')
print(total['White Percent'].describe())
# Out:
# Multiple stats for values in column A:
# count    61.000000
# mean     74.003279
# std       7.377081
# min      57.600000
# 25%      69.500000
# 50%      72.100000
# 75%      78.400000
# max      94.600000
# Name: White Percent, dtype: float64

# %%
print('\nMultiple stats for values in column A:')
print(total['Black Percent'].describe())
# Out:
# Multiple stats for values in column A:
# count    61.000000
# mean      5.954098
# std       2.703552
# min       1.500000
# 25%       3.900000
# 50%       5.400000
# 75%       7.600000
# max      12.400000
# Name: Black Percent, dtype: float64

# %%
print('\nMultiple stats for values in column A:')
print(total['Asian Percent'].describe())
# Out:
# Multiple stats for values in column A:
# count    61.000000
# mean     12.698361
# std       6.992579
# min       0.500000
# 25%       8.100000
# 50%      11.900000
# 75%      17.200000
# max      32.400000
# Name: Asian Percent, dtype: float64

# %%
total[total['Asian Percent']>32]
# Out:
#                                           Occupation  Total Estimate  \
# 8  ..Software developers, applications and system...       1050915.0
#
#    Total MOE3  White Estimate  White MOE3  White Percent White MOE3.1  \
# 8      9784.1        613055.0      6411.0           58.3          0.3
#
#    Black Estimate  Black MOE3  Black Percent Black MOE3.1  Asian Estimate  \
# 8         47520.0      1795.0            4.5          0.2        340775.0
#
#    Asian MOE3  Asian Percent Asian MOE3.1  Hispanic Estimate  Hispanic MOE3  \
# 8      4239.5           32.4          0.3            49565.0         1930.4
#
#    Hispanic Percent Hispanic MOE3.1      Type
# 8               4.7             0.2  subfield

# %%
total.plot.scatter(x='White Percent', y='Black Percent')
# Out:
# <AxesSubplot:xlabel='White Percent', ylabel='Black Percent'>

# %%
total['White Percent'].plot.hist();

# %%
total['Asian Percent'].plot.hist();

# %%
#categorizing the percentage of a race in the STEM field in comparison to that races percentage in the work force

def categorize_white(percent):
    if percent < 67.2: return 'less than pop'
    elif percent == 67.2: return 'equal to pop'
    elif percent > 67.2: return 'more than pop'
    else: return np.nan

total['White Representation'] = total['White Percent'].apply(categorize_white)

def categorize_black(percent):
    if percent < 11: return 'less than pop'
    elif percent == 11: return 'equal to pop'
    elif percent > 11: return 'more than pop'
    else: return np.nan

total['Black Representation'] = total['Black Percent'].apply(categorize_black)

def categorize_asian(percent):
    if percent < 5.9: return 'less than pop'
    elif percent == 5.9: return 'equal to pop'
    elif percent > 5.9: return 'more than pop'
    else: return np.nan

total['Asian Representation'] = total['Asian Percent'].apply(categorize_asian)

def categorize_hispanic(percent):
    if percent < 15.8: return 'less than pop'
    elif percent == 15.8: return 'equal to pop'
    elif percent > 15.8: return 'more than pop'
    else: return np.nan

total['Hispanic Representation'] = total['Hispanic Percent'].apply(categorize_hispanic)

# %%
#grouping the categorizations

wrep_data = total.groupby('White Representation').size().reset_index().rename(columns={0:'n_wrep'})
display(wrep_data)

brep_data = total.groupby('Black Representation').size().reset_index().rename(columns={0:'n_brep'})
display(brep_data)

arep_data = total.groupby('Asian Representation').size().reset_index().rename(columns={0:'n_arep'})
display(arep_data)

hrep_data = total.groupby('Hispanic Representation').size().reset_index().rename(columns={0:'n_hrep'})
display(hrep_data)
# Out:
#   White Representation  n_wrep
# 0         equal to pop       2
# 1        less than pop       8
# 2        more than pop      51
#   Black Representation  n_brep
# 0         equal to pop       1
# 1        less than pop      56
# 2        more than pop       4
#   Asian Representation  n_arep
# 0         equal to pop       1
# 1        less than pop      12
# 2        more than pop      48
#   Hispanic Representation  n_hrep
# 0            equal to pop       1
# 1           less than pop      59
# 2           more than pop       1

# %%
# compares percentage of white people in work force with percent in a specific occupation
wrep_data.plot.bar(
    x='White Representation', y='n_wrep',
    legend=None,                 
    rot=45,                                     
    color='#d9e3f0'                             
);

# compares percentage of black people in work force with percent in a specific occupation
brep_data.plot.bar(
    x='Black Representation', y='n_brep',
    legend=None,                                
    rot=45,                                     
    color='#f47373'                             
);

# compares percentage of asian people in work force with percent in a specific occupation
arep_data.plot.bar(
    x='Asian Representation', y='n_arep',
    legend=None,                                
    rot=45,                                     
    color='#37d67a'                            
);

# compares percentage of hispanic people in work force with percent in a specific occupation
hrep_data.plot.bar(
    x='Hispanic Representation', y='n_hrep',
    legend=None,                                
    rot=45,                                     
    color='#ba68c8'                             
);

# %%
degrees_by_race = pd.read_excel('../data/stem_degrees_race.xls')
display(degrees_by_race)
# Out:
#    Racial/ethnic distribution of S&E bachelor's degrees: 2000–12 \n(U.S. citizens & permanent residents)  \
# 0                                           (Percent)
# 1                                                Year
# 2                                                2000
# 3                                                2001
# 4                                                2002
# 5                                                2003
# 6                                                2004
# 7                                                2005
# 8                                                2006
# 9                                                2007
# 10                                               2008
# 11                                               2009
# 12                                               2010
# 13                                               2011
# 14                                               2012
#
# ...

# %%
#categorizing the percentage of a race in the STEM field in comparison to that races percentage in earning STEM degrees

def categorize_white_degree(percent):
    if percent < 62.7: return 'less than degree'
    elif percent == 62.7: return 'equal to degree'
    elif percent > 62.7: return 'more than degree'
    else: return np.nan

total['White Degree'] = total['White Percent'].apply(categorize_white_degree)

def categorize_black_degree(percent):
    if percent < 8.8: return 'less than degree'
    elif percent == 8.8: return 'equal to degree'
    elif percent > 8.8: return 'more than degree'
    else: return np.nan

total['Black Degree'] = total['Black Percent'].apply(categorize_black_degree)

def categorize_asian_degree(percent):
    if percent < 9.7: return 'less than degree'
    elif percent == 9.7: return 'equal to degree'
    elif percent > 9.7: return 'more than degree'
    else: return np.nan

total['Asian Degree'] = total['Asian Percent'].apply(categorize_asian_degree)

def categorize_hispanic_degree(percent):
    if percent < 10.3: return 'less than degree'
    elif percent == 10.3: return 'equal to degree'
    elif percent > 10.3: return 'more than degree'
    else: return np.nan

total['Hispanic Degree'] = total['Hispanic Percent'].apply(categorize_hispanic_degree)

# %%
#grouping the categorizations

wdeg_data = total.groupby('White Degree').size().reset_index().rename(columns={0:'n_wdeg'})
display(wdeg_data)

bdeg_data = total.groupby('Black Degree').size().reset_index().rename(columns={0:'n_bdeg'})
display(bdeg_data)

adeg_data = total.groupby('Asian Degree').size().reset_index().rename(columns={0:'n_adeg'})
display(adeg_data)

hdeg_data = total.groupby('Hispanic Degree').size().reset_index().rename(columns={0:'n_hdeg'})
display(hdeg_data)
# Out:
#        White Degree  n_wdeg
# 0  less than degree       3
# 1  more than degree      58
#        Black Degree  n_bdeg
# 0  less than degree      51
# 1  more than degree      10
#        Asian Degree  n_adeg
# 0  less than degree      20
# 1  more than degree      41
#     Hispanic Degree  n_hdeg
# 0  less than degree      53
# 1  more than degree       8

# %%
# compares percentage of white people in work force with percent in a specific occupation
wdeg_data.plot.bar(
    x='White Degree', y='n_wdeg',
    legend=None,                 
    rot=45,                                     
    color='#d9e3f0'                             
);

# compares percentage of black people in work force with percent in a specific occupation
bdeg_data.plot.bar(
    x='Black Degree', y='n_bdeg',
    legend=None,                                
    rot=45,                                     
    color='#f47373'                             
);

# compares percentage of asian people in work force with percent in a specific occupation
adeg_data.plot.bar(
    x='Asian Degree', y='n_adeg',
    legend=None,                                
    rot=45,                                     
    color='#37d67a'                            
);

# compares percentage of hispanic people in work force with percent in a specific occupation
hdeg_data.plot.bar(
    x='Hispanic Degree', y='n_hdeg',
    legend=None,                                
    rot=45,                                     
    color='#ba68c8'                             
);

# %%
degrees_by_gender = pd.read_excel('../data/stem_degrees_gender.xls')
display(degrees_by_gender)
# Out:
#   Number of S&E bachelor's degrees awarded, by sex: 2000–12 (all citizenship groups)  \
# 0                                                NaN
# 1                                              Total
# 2                                             Female
# 3                                               Male
#
#    Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0        2000        2001        2002        2003        2004        2005
# 1      398602      400435      415983      442755      458658      470214
# 2      200952      202664      211308      222940      230797      236290
# 3      197650      197771      204675      219815      227861      233924
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 0        2006        2007        2008         2009         2010         2011
# 1      478858      485772      496168       505435       525374       554365
# ...

# %%
male = pd.read_excel('../data/male_census_occupations.xlsx')
display(male)
# Out:
#                                       Male Occupation  Totale Estimate  \
# 0                   Civilian employed age 25 and over       66649440.0
# 1                                         Total STEM2        5978821.0
# 2                              .Computer Occupations:        3082225.0
# 3         ..Computer and information systems managers         392410.0
# 4      ..Computer and information research scientists          11525.0
# ..                                                ...              ...
# 56        ..Agricultural and food science technicians          17920.0
# 57                           ..Biological technicians           8975.0
# 58                             ..Chemical technicians          40915.0
# 59  ..Geological and petroleum technicians and nuc...          14025.0
# 60  ..Miscellaneous life, physical, and social sci...          71780.0
#
#     Total MOE3  Total Percent Total MOE3.1  White Estimate  White MOE3  \
# ...

# %%
female = pd.read_excel('../data/female_census_occupations.xlsx')
display(female)
# Out:
#                                     Female Occupation  Totale Estimate  \
# 0                   Civilian employed age 25 and over       59201492.0
# 1                                         Total STEM2        2001217.0
# 2                              .Computer Occupations:        1038235.0
# 3         ..Computer and information systems managers         153170.0
# 4      ..Computer and information research scientists           4350.0
# ..                                                ...              ...
# 56        ..Agricultural and food science technicians          11955.0
# 57                           ..Biological technicians           7880.0
# 58                             ..Chemical technicians          18645.0
# 59  ..Geological and petroleum technicians and nuc...           4420.0
# 60  ..Miscellaneous life, physical, and social sci...          63320.0
#
#     Total MOE3  Total Percent Total MOE3.1  White Estimate  White MOE3  \
# ...

# %%
#categorizing the percentage of a sex in the STEM field in comparison to that sex's percentage in earning STEM degrees

def categorize_male(percent):
    if percent < ((291791/589330)*100): return 'less than degree'
    elif percent == ((291791/589330)*100): return 'equal to degree'
    elif percent > ((291791/589330)*100): return 'more than degree'
    else: return np.nan

male['Male Degree'] = male['Total Percent'].apply(categorize_male)

def categorize_female(percent):
    if percent < ((297539/589330)*100): return 'less than degree'
    elif percent == ((297539/589330)*100): return 'equal to degree'
    elif percent > ((297539/589330)*100): return 'more than degree'
    else: return np.nan

female['Female Degree'] = female['Total Percent'].apply(categorize_female)

# %%
#grouping the categorizations

mdeg_data = male.groupby('Male Degree').size().reset_index().rename(columns={0:'n_mdeg'})
display(mdeg_data)

fdeg_data = female.groupby('Female Degree').size().reset_index().rename(columns={0:'n_fdeg'})
display(fdeg_data)
# Out:
#         Male Degree  n_mdeg
# 0  less than degree       4
# 1  more than degree      57
#       Female Degree  n_fdeg
# 0  less than degree      57
# 1  more than degree       4

# %%
# compares percentage of white people in work force with percent in a specific occupation
mdeg_data.plot.bar(
    x='Male Degree', y='n_mdeg',
    legend=None,                 
    rot=45,                                     
    color='#d9e3f0'                             
);

# compares percentage of black people in work force with percent in a specific occupation
fdeg_data.plot.bar(
    x='Female Degree', y='n_fdeg',
    legend=None,                                
    rot=45,                                     
    color='#f47373'                             
);

# %%
degree = pd.read_excel('../data/stemdegrees2020clean.xlsx')
display(degree)
# Out:
#                                           Sex and year  \
# 0                                                  1.0
# 1                                                  NaN
# 2                                                Total
# 3                                             2010-11
# 4                                             2011-12
# ..                                                 ...
# 202                                           2017-18
# 203                                           2018-19
# 204                                            2019-20
# 205  NOTE: Data in this table represent the 50 stat...
# 206  SOURCE: U.S. Department of Education, National...
#
#                                   Total Number  White Number  Black Number  \
# 0                                          2.0           3.0           4.0
# 1    Total, all levels of degrees/certificates           NaN           NaN
# 2                                          NaN           NaN           NaN
# ...

# %%
totaldegree = degree[degree['Type'] == 'Total']
totaldegree
# Out:
#    Sex and year Total Number  White Number  Black Number  His- panic Number  \
# 3      2010-11      531018.0      319327.0       47014.0            45794.0
# 4      2011-12      556696.0      333652.0       47004.0            49262.0
# 5      2012-13      574000.0      337241.0       47710.0            53015.0
# 6      2013-14      604167.0      348586.0       49455.0            58104.0
# 7      2014-15      635800.0      353950.0       50760.0            63689.0
# 8      2015-16      668091.0      358113.0       48512.0            67822.0
# 9      2016-17      704861.0      367260.0       49888.0            74461.0
# 10     2017-18      733459.0      376795.0       51256.0            81816.0
# 11     2018-19      756960.0      384765.0       53993.0            89797.0
# 12      2019-20     773971.0      385132.0       55642.0            94927.0
#
#     Asian Number  Pacific Islander Number  \
# 3        50250.0                   1211.0
# 4        52336.0                   1334.0
# ...

# %%
# totaldegree.plot.scatter(x='Sex and year', y='White Number')

# %%
fdegree = degree[degree['Type'] == 'Females']
fdegree
# Out:
#    Sex and year Total Number  White Number  Black Number  His- panic Number  \
# 25     2010-11      160096.0       90623.0       16468.0            12917.0
# 26     2011-12      168991.0       94649.0       16852.0            14411.0
# 27     2012-13      176777.0       97553.0       17078.0            15983.0
# 28     2013-14      186620.0      100687.0       17443.0            17521.0
# 29     2014-15      199025.0      103739.0       17929.0            19842.0
# 30     2015-16      212532.0      106718.0       18131.0            21876.0
# 31     2016-17      226032.0      110383.0       18965.0            24384.0
# 32     2017-18      237873.0      113541.0       19456.0            27015.0
# 33     2018-19      249921.0      117788.0       21055.0            30034.0
# 34      2019-20     263034.0      121811.0       22148.0            32964.0
#
#     Asian Number  Pacific Islander Number  \
# 25       19057.0                    418.0
# 26       19975.0                    455.0
# ...

# %%
totaldegree.plot.scatter(x='Sex and year', y='Total Number')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Sex and year', ylabel='Total Number'>

# %%
fdegree.plot.scatter(x='Sex and year', y='Total Number')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Sex and year', ylabel='Total Number'>

# %%
mdegree = degree[degree['Type'] == 'Males']
# mdegree.plot.scatter(x='Sex and year', y='Total Number')

# %%
def cast_to_single_year(string_with_years):
    """converts a string to a number by removing commas and percentage signs
    """
    last_two_digits = string_with_years[5:]
    full_year = '20' + last_two_digits
    number = float(full_year)
    return number

def cast_to_number(string_with_symbols):
    """converts a string to a number by removing commas and percentage signs
    """
    if isinstance(string_with_symbols, float):  # already a number!
        return string_with_symbols
    no_commas = string_with_symbols.replace(',', '')
    no_percent = no_commas.replace('%', '')
    number = float(no_percent)
    return number

# %%
totaldegree.is_copy = False

totaldegree['Sex and year'] = totaldegree['Sex and year'].apply(cast_to_single_year)
totaldegree['Total Number'] = totaldegree['Total Number'].apply(cast_to_number)
totaldegree
# Out:
# C:\Users\Srikar\AppData\Local\Temp\ipykernel_14028\2774602639.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   totaldegree['Sex and year'] = totaldegree['Sex and year'].apply(cast_to_single_year)
# C:\Users\Srikar\AppData\Local\Temp\ipykernel_14028\2774602639.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   totaldegree['Total Number'] = totaldegree['Total Number'].apply(cast_to_number)
#     Sex and year  Total Number  White Number  Black Number  His- panic Number  \
# ...

# %%
fdegree.is_copy = False
fdegree['Sex and year'] = fdegree['Sex and year'].apply(cast_to_single_year)
fdegree['Total Number'] = fdegree['Total Number'].apply(cast_to_number)
mdegree['Sex and year'] = mdegree['Sex and year'].apply(cast_to_single_year)
mdegree['Total Number'] = mdegree['Total Number'].apply(cast_to_number)
# Out:
# C:\Users\Srikar\AppData\Local\Temp\ipykernel_14028\863895124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fdegree['Sex and year'] = fdegree['Sex and year'].apply(cast_to_single_year)
# C:\Users\Srikar\AppData\Local\Temp\ipykernel_14028\863895124.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fdegree['Total Number'] = fdegree['Total Number'].apply(cast_to_number)
# C:\Users\Srikar\AppData\Local\Temp\ipykernel_14028\863895124.py:4: SettingWithCopyWarning:
# ...

# %%
plt.scatter(fdegree['Sex and year'],fdegree['Total Number'], color='#ff763f', label='Female Degrees')
plt.scatter(mdegree['Sex and year'],mdegree['Total Number'], color='#0508b2', label='Male Degrees')
plt.xlabel('Year', fontsize=14)
plt.ylabel('Total Number', fontsize=14)
plt.title('Change in Degrees earned in STEM by Gender(2011-2020)', fontsize=16)
plt.xticks(fdegree['Sex and year'])
plt.ylim(0,600000)
plt.legend()

# %%
linear_modelf = np.polyfit(fdegree['Sex and year'], fdegree['Total Number'], 1)
linear_modelm = np.polyfit(mdegree['Sex and year'], mdegree['Total Number'], 1)
# Out:
# array([ 1.69085939e+04, -3.36334589e+07])

# %%
linear_modelf_fn = np.poly1d(linear_modelf)
linear_modelm_fn = np.poly1d(linear_modelm)

# %%
# draw the data
plt.scatter(fdegree['Sex and year'], fdegree['Total Number'], label='Female')
plt.scatter(mdegree['Sex and year'], mdegree['Total Number'], label='Male')

# # add the linear fit line    # plt.plot draws a straight line connecting the points
plt.plot(fdegree['Sex and year'], linear_modelf_fn(fdegree['Sex and year']), color="red", label='linear fit f')
plt.plot(mdegree['Sex and year'], linear_modelm_fn(mdegree['Sex and year']), color="green", label='linear fit m')

# # add text box for the statistics
stats = (f'$m = {linear_modelf[0]:.2f}$\n'
         f'$b = {linear_modelf[1]:.2f}$')
statsm = (f'$m = {linear_modelm[0]:.2f}$\n'
         f'$b = {linear_modelm[1]:.2f}$')
bbox = dict(boxstyle='round', fc='lightgrey', ec='lightgrey', alpha=0.5)
#plt.text(80, -80, stats, fontsize=12, bbox=bbox, horizontalalignment='left')

plt.ylim(0, 600000)
plt.legend()
plt.show()

# %%
matrix = mdegree.corr()
matrix
# Out:
#                                         Sex and year  Total Number  \
# Sex and year                                1.000000      0.993863
# Total Number                                0.993863      1.000000
# White Number                                0.971485      0.978874
# Black Number                                0.699798      0.656473
# His- panic Number                           0.992829      0.985951
# Asian Number                                0.991268      0.984226
# Pacific Islander Number                    -0.042541     -0.044251
# American Indian/ Alaska Native Number      -0.977029     -0.971370
# Two or more races Number                    0.994880      0.994265
# Non-resident alien Number                   0.948953      0.971801
# Total Percent                               0.385337      0.351799
# White Percent                              -0.993365     -0.982773
# Black Percent                              -0.927357     -0.948092
# ...

# %%
sns.set(rc={"figure.figsize":(12, 10)})
sns.heatmap(matrix, annot=True, vmax=1, vmin=-1, center=0, cmap='PiYG')
#sns.heatmap(matrix, annot=True, cmap='PiYG')
plt.show()

# %%
mdegree
# Out:
#     Sex and year  Total Number  White Number  Black Number  His- panic Number  \
# 14        2011.0      370922.0      228704.0       30546.0            32877.0
# 15        2012.0      387705.0      239003.0       30152.0            34851.0
# 16        2013.0      397223.0      239688.0       30632.0            37032.0
# 17        2014.0      417547.0      247899.0       32012.0            40583.0
# 18        2015.0      436775.0      250211.0       32831.0            43847.0
# 19        2016.0      455559.0      251395.0       30381.0            45946.0
# 20        2017.0      478829.0      256877.0       30923.0            50077.0
# 21        2018.0      495586.0      263254.0       31800.0            54801.0
# 22        2019.0      507039.0      266977.0       32938.0            59763.0
# 23        2020.0      510937.0      263321.0       33494.0            61963.0
#
#     Asian Number  Pacific Islander Number  \
# 14       31193.0                    793.0
# ...

# %%
# sns.pairplot(totaldegree, corner=True);
